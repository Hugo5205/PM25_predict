# %%
from kafka import KafkaConsumer
import sys, json, pymongo
import datetime


if __name__ == "__main__":

    # 與 MongoDB連線
    client = pymongo.MongoClient(host="mongodb", port=27017)
    # 指定為 test 資料庫
    db = client.hugo
    # 指定 temp_humidity 集合, MongoDB的每個資料庫又包含許多集合(collection), 類似於關聯性資料庫中的表
    collection = db.pm25_2020

    # 設定要連線到Kafka集群的相關設定, 產生一個Kafka的Consumer的實例
    consumer = KafkaConsumer(
        # 指定Kafka集群伺服器
        bootstrap_servers=["kafka:9092"],
        # ConsumerGroup的名稱, 可以不指定
        #group_id="cg_001",
        # 指定msgKey的反序列化器, 若Key為None, 無法反序列化
        # key_deserializer=bytes.decode,
        # 指定msgValue的反序列化器
        #value_deserializer=bytes.decode,
        value_deserializer=lambda m: json.loads(m.decode('ascii')),
        # 是否從這個ConsumerGroup尚未讀取的partition / offset開始讀
        auto_offset_reset="earliest",
    )
   
    # 讓Consumer向Kafka集群訂閱指定的topic
    consumer.subscribe(topics="pm25")
    
    # 持續的拉取Kafka有進來的訊息
    try:
        print("Now listening for incoming messages ...")
        # 持續監控是否有新的record進來
        for record in consumer:
            topic = record.topic
            partition = record.partition
            offset = record.offset
            timestamp = record.timestamp
            # 取出msgKey與msgValue
            msgKey = record.key
            msgValue = record.value
            msgValue["timestamp"] = datetime.datetime.strptime(msgValue["timestamp"], '%Y-%m-%d %H:%M:%S') + datetime.timedelta(hours = 8) 
            
            # 秀出metadata與msgKey & msgValue訊息
            print("topic=%s, partition=%s, offset=%s : (key=%s, value=%s)" % (record.topic, record.partition,record.offset, record.key, record.value))
            j = {"timestamp": msgValue["timestamp"].strftime("%Y/%m/%d %H:%M:%S"), "Temperature": msgValue["Temperature"], "Humidity": msgValue["Humidity"], "PM25": msgValue["PM2.5"], "PM25predict": msgValue["PM25predict"] }
            print("json=",  j)
            #print(record.value)
            # 將資料存入 mongodb
            # 存入單筆
            result = collection.insert_one(j)
            # 存入多筆
            #result = collection.insert_many()
            print(result)

    except:
        # 錯誤處理
        e_type, e_value, e_traceback = sys.exc_info()
        print("type ==> %s" % (e_type))
        print("value ==> %s" % (e_value))
        print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
        print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
        print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))
    finally:
        consumer.close()
# Out:
# Now listening for incoming messages ...
# topic=pm25, partition=0, offset=0 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 30, 15, 31, 25), 'Temperature': '19.8', 'Humidity': '76.9', 'PM2.5': '21.0', 'PM25predict': '16.23'})
# json= {'timestamp': '2019/12/30 15:31:25', 'Temperature': '19.8', 'Humidity': '76.9', 'PM25': '21.0', 'PM25predict': '16.23'}
# <pymongo.results.InsertOneResult object at 0x7f770d789748>
# topic=pm25, partition=0, offset=1 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 30, 16, 0, 3), 'Temperature': '19.2', 'Humidity': '81.6', 'PM2.5': '12.0', 'PM25predict': '15.75'})
# json= {'timestamp': '2019/12/30 16:00:03', 'Temperature': '19.2', 'Humidity': '81.6', 'PM25': '12.0', 'PM25predict': '15.75'}
# <pymongo.results.InsertOneResult object at 0x7f770d789788>
# topic=pm25, partition=0, offset=2 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 30, 17, 0, 4), 'Temperature': '19.5', 'Humidity': '79.4', 'PM2.5': '11.0', 'PM25predict': '15.98'})
# json= {'timestamp': '2019/12/30 17:00:04', 'Temperature': '19.5', 'Humidity': '79.4', 'PM25': '11.0', 'PM25predict': '15.98'}
# <pymongo.results.InsertOneResult object at 0x7f770d789808>
# topic=pm25, partition=0, offset=3 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 30, 18, 0, 3), 'Temperature': '19.5', 'Humidity': '78.7', 'PM2.5': '13.0', 'PM25predict': '16.02'})
# json= {'timestamp': '2019/12/30 18:00:03', 'Temperature': '19.5', 'Humidity': '78.7', 'PM25': '13.0', 'PM25predict': '16.02'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3ac8>
# topic=pm25, partition=0, offset=4 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 30, 19, 0, 4), 'Temperature': '19.3', 'Humidity': '80.1', 'PM2.5': '21.0', 'PM25predict': '15.87'})
# json= {'timestamp': '2019/12/30 19:00:04', 'Temperature': '19.3', 'Humidity': '80.1', 'PM25': '21.0', 'PM25predict': '15.87'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be0c8>
# topic=pm25, partition=0, offset=5 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 30, 20, 0, 3), 'Temperature': '19.2', 'Humidity': '80.1', 'PM2.5': '17.0', 'PM25predict': '15.83'})
# json= {'timestamp': '2019/12/30 20:00:03', 'Temperature': '19.2', 'Humidity': '80.1', 'PM25': '17.0', 'PM25predict': '15.83'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be088>
# topic=pm25, partition=0, offset=6 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 30, 21, 0, 3), 'Temperature': '18.8', 'Humidity': '79.5', 'PM2.5': '20.0', 'PM25predict': '15.74'})
# json= {'timestamp': '2019/12/30 21:00:03', 'Temperature': '18.8', 'Humidity': '79.5', 'PM25': '20.0', 'PM25predict': '15.74'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3cc8>
# topic=pm25, partition=0, offset=7 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 30, 22, 0, 3), 'Temperature': '18.2', 'Humidity': '79.1', 'PM2.5': '21.0', 'PM25predict': '15.56'})
# json= {'timestamp': '2019/12/30 22:00:03', 'Temperature': '18.2', 'Humidity': '79.1', 'PM25': '21.0', 'PM25predict': '15.56'}
# <pymongo.results.InsertOneResult object at 0x7f771f70d6c8>
# topic=pm25, partition=0, offset=8 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 30, 23, 0, 4), 'Temperature': '18.1', 'Humidity': '78.6', 'PM2.5': '17.0', 'PM25predict': '15.56'})
# json= {'timestamp': '2019/12/30 23:00:04', 'Temperature': '18.1', 'Humidity': '78.6', 'PM25': '17.0', 'PM25predict': '15.56'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be148>
# topic=pm25, partition=0, offset=9 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 1, 0, 3), 'Temperature': '17.6', 'Humidity': '77.7', 'PM2.5': '16.0', 'PM25predict': '15.45'})
# json= {'timestamp': '2019/12/31 01:00:03', 'Temperature': '17.6', 'Humidity': '77.7', 'PM25': '16.0', 'PM25predict': '15.45'}
# <pymongo.results.InsertOneResult object at 0x7f771c45d888>
# topic=pm25, partition=0, offset=10 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 2, 0, 4), 'Temperature': '17.3', 'Humidity': '77.1', 'PM2.5': '17.0', 'PM25predict': '15.38'})
# json= {'timestamp': '2019/12/31 02:00:04', 'Temperature': '17.3', 'Humidity': '77.1', 'PM25': '17.0', 'PM25predict': '15.38'}
# <pymongo.results.InsertOneResult object at 0x7f771f706848>
# topic=pm25, partition=0, offset=11 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 3, 0, 3), 'Temperature': '16.9', 'Humidity': '78.4', 'PM2.5': '22.0', 'PM25predict': '15.17'})
# json= {'timestamp': '2019/12/31 03:00:03', 'Temperature': '16.9', 'Humidity': '78.4', 'PM25': '22.0', 'PM25predict': '15.17'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be148>
# topic=pm25, partition=0, offset=12 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 4, 0, 4), 'Temperature': '16.5', 'Humidity': '78.4', 'PM2.5': '24.0', 'PM25predict': '15.04'})
# json= {'timestamp': '2019/12/31 04:00:04', 'Temperature': '16.5', 'Humidity': '78.4', 'PM25': '24.0', 'PM25predict': '15.04'}
# <pymongo.results.InsertOneResult object at 0x7f770d789848>
# topic=pm25, partition=0, offset=13 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 5, 0, 3), 'Temperature': '16.3', 'Humidity': '77.9', 'PM2.5': '27.0', 'PM25predict': '15.0'})
# json= {'timestamp': '2019/12/31 05:00:03', 'Temperature': '16.3', 'Humidity': '77.9', 'PM25': '27.0', 'PM25predict': '15.0'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be088>
# topic=pm25, partition=0, offset=14 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 6, 0, 2), 'Temperature': '16.0', 'Humidity': '77.5', 'PM2.5': '28.0', 'PM25predict': '14.93'})
# json= {'timestamp': '2019/12/31 06:00:02', 'Temperature': '16.0', 'Humidity': '77.5', 'PM25': '28.0', 'PM25predict': '14.93'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be0c8>
# topic=pm25, partition=0, offset=15 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 7, 0, 3), 'Temperature': '16.1', 'Humidity': '76.5', 'PM2.5': '34.0', 'PM25predict': '15.02'})
# json= {'timestamp': '2019/12/31 07:00:03', 'Temperature': '16.1', 'Humidity': '76.5', 'PM25': '34.0', 'PM25predict': '15.02'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be1c8>
# topic=pm25, partition=0, offset=16 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 8, 0, 4), 'Temperature': '16.0', 'Humidity': '79.1', 'PM2.5': '11.0', 'PM25predict': '14.87'})
# json= {'timestamp': '2019/12/31 08:00:04', 'Temperature': '16.0', 'Humidity': '79.1', 'PM25': '11.0', 'PM25predict': '14.87'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be148>
# topic=pm25, partition=0, offset=17 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 9, 0, 4), 'Temperature': '15.7', 'Humidity': '79.3', 'PM2.5': '19.0', 'PM25predict': '14.76'})
# json= {'timestamp': '2019/12/31 09:00:04', 'Temperature': '15.7', 'Humidity': '79.3', 'PM25': '19.0', 'PM25predict': '14.76'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3dc8>
# topic=pm25, partition=0, offset=18 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 10, 0, 3), 'Temperature': '15.5', 'Humidity': '77.5', 'PM2.5': '20.0', 'PM25predict': '14.8'})
# json= {'timestamp': '2019/12/31 10:00:03', 'Temperature': '15.5', 'Humidity': '77.5', 'PM25': '20.0', 'PM25predict': '14.8'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be1c8>
# topic=pm25, partition=0, offset=19 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 11, 0, 3), 'Temperature': '15.5', 'Humidity': '73.6', 'PM2.5': '19.0', 'PM25predict': '15.03'})
# json= {'timestamp': '2019/12/31 11:00:03', 'Temperature': '15.5', 'Humidity': '73.6', 'PM25': '19.0', 'PM25predict': '15.03'}
# <pymongo.results.InsertOneResult object at 0x7f771f710248>
# topic=pm25, partition=0, offset=20 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 12, 0, 3), 'Temperature': '15.5', 'Humidity': '73.8', 'PM2.5': '21.0', 'PM25predict': '15.02'})
# json= {'timestamp': '2019/12/31 12:00:03', 'Temperature': '15.5', 'Humidity': '73.8', 'PM25': '21.0', 'PM25predict': '15.02'}
# <pymongo.results.InsertOneResult object at 0x7f771c4cb1c8>
# topic=pm25, partition=0, offset=21 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 13, 0, 3), 'Temperature': '15.7', 'Humidity': '72.6', 'PM2.5': '31.0', 'PM25predict': '15.15'})
# json= {'timestamp': '2019/12/31 13:00:03', 'Temperature': '15.7', 'Humidity': '72.6', 'PM25': '31.0', 'PM25predict': '15.15'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be088>
# topic=pm25, partition=0, offset=22 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 14, 0, 3), 'Temperature': '15.9', 'Humidity': '69.2', 'PM2.5': '35.0', 'PM25predict': '15.42'})
# json= {'timestamp': '2019/12/31 14:00:03', 'Temperature': '15.9', 'Humidity': '69.2', 'PM25': '35.0', 'PM25predict': '15.42'}
# <pymongo.results.InsertOneResult object at 0x7f770d7a6d48>
# topic=pm25, partition=0, offset=23 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 15, 0, 3), 'Temperature': '15.7', 'Humidity': '68.8', 'PM2.5': '24.0', 'PM25predict': '15.38'})
# json= {'timestamp': '2019/12/31 15:00:03', 'Temperature': '15.7', 'Humidity': '68.8', 'PM25': '24.0', 'PM25predict': '15.38'}
# <pymongo.results.InsertOneResult object at 0x7f770d7897c8>
# topic=pm25, partition=0, offset=24 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 16, 0, 2), 'Temperature': '15.3', 'Humidity': '71.4', 'PM2.5': '32.0', 'PM25predict': '15.09'})
# json= {'timestamp': '2019/12/31 16:00:02', 'Temperature': '15.3', 'Humidity': '71.4', 'PM25': '32.0', 'PM25predict': '15.09'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3a08>
# topic=pm25, partition=0, offset=25 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 17, 0, 3), 'Temperature': '15.5', 'Humidity': '70.1', 'PM2.5': '33.0', 'PM25predict': '15.23'})
# json= {'timestamp': '2019/12/31 17:00:03', 'Temperature': '15.5', 'Humidity': '70.1', 'PM25': '33.0', 'PM25predict': '15.23'}
# <pymongo.results.InsertOneResult object at 0x7f770d789848>
# topic=pm25, partition=0, offset=26 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 18, 0, 3), 'Temperature': '15.2', 'Humidity': '68.8', 'PM2.5': '39.0', 'PM25predict': '15.21'})
# json= {'timestamp': '2019/12/31 18:00:03', 'Temperature': '15.2', 'Humidity': '68.8', 'PM25': '39.0', 'PM25predict': '15.21'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be108>
# topic=pm25, partition=0, offset=27 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 19, 0, 2), 'Temperature': '15.2', 'Humidity': '68.8', 'PM2.5': '41.0', 'PM25predict': '15.21'})
# json= {'timestamp': '2019/12/31 19:00:02', 'Temperature': '15.2', 'Humidity': '68.8', 'PM25': '41.0', 'PM25predict': '15.21'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3e08>
# topic=pm25, partition=0, offset=28 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 20, 0, 3), 'Temperature': '15.0', 'Humidity': '69.2', 'PM2.5': '33.0', 'PM25predict': '15.12'})
# json= {'timestamp': '2019/12/31 20:00:03', 'Temperature': '15.0', 'Humidity': '69.2', 'PM25': '33.0', 'PM25predict': '15.12'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3dc8>
# topic=pm25, partition=0, offset=29 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 21, 0, 3), 'Temperature': '14.8', 'Humidity': '69.1', 'PM2.5': '23.0', 'PM25predict': '15.06'})
# json= {'timestamp': '2019/12/31 21:00:03', 'Temperature': '14.8', 'Humidity': '69.1', 'PM25': '23.0', 'PM25predict': '15.06'}
# <pymongo.results.InsertOneResult object at 0x7f770d7a6fc8>
# topic=pm25, partition=0, offset=30 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 22, 0, 3), 'Temperature': '14.5', 'Humidity': '70.1', 'PM2.5': '23.0', 'PM25predict': '14.9'})
# json= {'timestamp': '2019/12/31 22:00:03', 'Temperature': '14.5', 'Humidity': '70.1', 'PM25': '23.0', 'PM25predict': '14.9'}
# <pymongo.results.InsertOneResult object at 0x7f771c4cb1c8>
# topic=pm25, partition=0, offset=31 : (key=None, value={'timestamp': datetime.datetime(2019, 12, 31, 23, 0, 3), 'Temperature': '15.0', 'Humidity': '68.7', 'PM2.5': '22.0', 'PM25predict': '15.14'})
# json= {'timestamp': '2019/12/31 23:00:03', 'Temperature': '15.0', 'Humidity': '68.7', 'PM25': '22.0', 'PM25predict': '15.14'}
# <pymongo.results.InsertOneResult object at 0x7f7720f43608>
# topic=pm25, partition=0, offset=32 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 0, 0, 3), 'Temperature': '15.1', 'Humidity': '69.4', 'PM2.5': '26.0', 'PM25predict': '15.13'})
# json= {'timestamp': '2020/01/01 00:00:03', 'Temperature': '15.1', 'Humidity': '69.4', 'PM25': '26.0', 'PM25predict': '15.13'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3a88>
# topic=pm25, partition=0, offset=33 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 1, 0, 3), 'Temperature': '15.2', 'Humidity': '68.8', 'PM2.5': '25.0', 'PM25predict': '15.2'})
# json= {'timestamp': '2020/01/01 01:00:03', 'Temperature': '15.2', 'Humidity': '68.8', 'PM25': '25.0', 'PM25predict': '15.2'}
# <pymongo.results.InsertOneResult object at 0x7f770d7897c8>
# topic=pm25, partition=0, offset=34 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 2, 0, 3), 'Temperature': '15.2', 'Humidity': '68.8', 'PM2.5': '22.0', 'PM25predict': '15.2'})
# json= {'timestamp': '2020/01/01 02:00:03', 'Temperature': '15.2', 'Humidity': '68.8', 'PM25': '22.0', 'PM25predict': '15.2'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3b48>
# topic=pm25, partition=0, offset=35 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 3, 0, 3), 'Temperature': '15.4', 'Humidity': '70.7', 'PM2.5': '25.0', 'PM25predict': '15.15'})
# json= {'timestamp': '2020/01/01 03:00:03', 'Temperature': '15.4', 'Humidity': '70.7', 'PM25': '25.0', 'PM25predict': '15.15'}
# <pymongo.results.InsertOneResult object at 0x7f771f710248>
# topic=pm25, partition=0, offset=36 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 4, 0, 3), 'Temperature': '15.0', 'Humidity': '72.4', 'PM2.5': '16.0', 'PM25predict': '14.91'})
# json= {'timestamp': '2020/01/01 04:00:03', 'Temperature': '15.0', 'Humidity': '72.4', 'PM25': '16.0', 'PM25predict': '14.91'}
# <pymongo.results.InsertOneResult object at 0x7f771c4cb1c8>
# topic=pm25, partition=0, offset=37 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 5, 0, 2), 'Temperature': '14.9', 'Humidity': '72.9', 'PM2.5': '14.0', 'PM25predict': '14.85'})
# json= {'timestamp': '2020/01/01 05:00:02', 'Temperature': '14.9', 'Humidity': '72.9', 'PM25': '14.0', 'PM25predict': '14.85'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3ec8>
# topic=pm25, partition=0, offset=38 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 6, 0, 2), 'Temperature': '15.3', 'Humidity': '72.1', 'PM2.5': '16.0', 'PM25predict': '15.02'})
# json= {'timestamp': '2020/01/01 06:00:02', 'Temperature': '15.3', 'Humidity': '72.1', 'PM25': '16.0', 'PM25predict': '15.02'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3b48>
# topic=pm25, partition=0, offset=39 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 7, 0, 3), 'Temperature': '15.4', 'Humidity': '72.2', 'PM2.5': '12.0', 'PM25predict': '15.05'})
# json= {'timestamp': '2020/01/01 07:00:03', 'Temperature': '15.4', 'Humidity': '72.2', 'PM25': '12.0', 'PM25predict': '15.05'}
# <pymongo.results.InsertOneResult object at 0x7f771c45d888>
# topic=pm25, partition=0, offset=40 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 8, 0, 3), 'Temperature': '15.6', 'Humidity': '72.4', 'PM2.5': '16.0', 'PM25predict': '15.14'})
# json= {'timestamp': '2020/01/01 08:00:03', 'Temperature': '15.6', 'Humidity': '72.4', 'PM25': '16.0', 'PM25predict': '15.14'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3a08>
# topic=pm25, partition=0, offset=41 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 9, 0, 3), 'Temperature': '16.1', 'Humidity': '70.4', 'PM2.5': '12.0', 'PM25predict': '15.42'})
# json= {'timestamp': '2020/01/01 09:00:03', 'Temperature': '16.1', 'Humidity': '70.4', 'PM25': '12.0', 'PM25predict': '15.42'}
# <pymongo.results.InsertOneResult object at 0x7f771c4c1388>
# topic=pm25, partition=0, offset=42 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 10, 0, 3), 'Temperature': '16.3', 'Humidity': '70.0', 'PM2.5': '11.0', 'PM25predict': '15.51'})
# json= {'timestamp': '2020/01/01 10:00:03', 'Temperature': '16.3', 'Humidity': '70.0', 'PM25': '11.0', 'PM25predict': '15.51'}
# <pymongo.results.InsertOneResult object at 0x7f7720f43608>
# topic=pm25, partition=0, offset=43 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 11, 0, 2), 'Temperature': '17.0', 'Humidity': '68.6', 'PM2.5': '9.0', 'PM25predict': '15.82'})
# json= {'timestamp': '2020/01/01 11:00:02', 'Temperature': '17.0', 'Humidity': '68.6', 'PM25': '9.0', 'PM25predict': '15.82'}
# <pymongo.results.InsertOneResult object at 0x7f770d7a65c8>
# topic=pm25, partition=0, offset=44 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 12, 0, 3), 'Temperature': '17.4', 'Humidity': '67.1', 'PM2.5': '7.0', 'PM25predict': '16.04'})
# json= {'timestamp': '2020/01/01 12:00:03', 'Temperature': '17.4', 'Humidity': '67.1', 'PM25': '7.0', 'PM25predict': '16.04'}
# <pymongo.results.InsertOneResult object at 0x7f770d7a6d48>
# topic=pm25, partition=0, offset=45 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 13, 0, 3), 'Temperature': '17.1', 'Humidity': '67.9', 'PM2.5': '8.0', 'PM25predict': '15.89'})
# json= {'timestamp': '2020/01/01 13:00:03', 'Temperature': '17.1', 'Humidity': '67.9', 'PM25': '8.0', 'PM25predict': '15.89'}
# <pymongo.results.InsertOneResult object at 0x7f771f706848>
# topic=pm25, partition=0, offset=46 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 14, 0, 3), 'Temperature': '16.9', 'Humidity': '68.5', 'PM2.5': '11.0', 'PM25predict': '15.79'})
# json= {'timestamp': '2020/01/01 14:00:03', 'Temperature': '16.9', 'Humidity': '68.5', 'PM25': '11.0', 'PM25predict': '15.79'}
# <pymongo.results.InsertOneResult object at 0x7f771f70d6c8>
# topic=pm25, partition=0, offset=47 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 15, 0, 4), 'Temperature': '17.0', 'Humidity': '69.1', 'PM2.5': '13.0', 'PM25predict': '15.78'})
# json= {'timestamp': '2020/01/01 15:00:04', 'Temperature': '17.0', 'Humidity': '69.1', 'PM25': '13.0', 'PM25predict': '15.78'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3a88>
# topic=pm25, partition=0, offset=48 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 16, 0, 4), 'Temperature': '17.2', 'Humidity': '67.2', 'PM2.5': '7.0', 'PM25predict': '15.96'})
# json= {'timestamp': '2020/01/01 16:00:04', 'Temperature': '17.2', 'Humidity': '67.2', 'PM25': '7.0', 'PM25predict': '15.96'}
# <pymongo.results.InsertOneResult object at 0x7f771f710248>
# topic=pm25, partition=0, offset=49 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 17, 0, 3), 'Temperature': '16.8', 'Humidity': '70.0', 'PM2.5': '7.0', 'PM25predict': '15.66'})
# json= {'timestamp': '2020/01/01 17:00:03', 'Temperature': '16.8', 'Humidity': '70.0', 'PM25': '7.0', 'PM25predict': '15.66'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be108>
# topic=pm25, partition=0, offset=50 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 18, 0, 4), 'Temperature': '16.4', 'Humidity': '72.2', 'PM2.5': '9.0', 'PM25predict': '15.4'})
# json= {'timestamp': '2020/01/01 18:00:04', 'Temperature': '16.4', 'Humidity': '72.2', 'PM25': '9.0', 'PM25predict': '15.4'}
# <pymongo.results.InsertOneResult object at 0x7f770d789848>
# topic=pm25, partition=0, offset=51 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 19, 0, 4), 'Temperature': '16.4', 'Humidity': '71.3', 'PM2.5': '10.0', 'PM25predict': '15.45'})
# json= {'timestamp': '2020/01/01 19:00:04', 'Temperature': '16.4', 'Humidity': '71.3', 'PM25': '10.0', 'PM25predict': '15.45'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3f88>
# topic=pm25, partition=0, offset=52 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 20, 0, 3), 'Temperature': '16.4', 'Humidity': '71.8', 'PM2.5': '10.0', 'PM25predict': '15.42'})
# json= {'timestamp': '2020/01/01 20:00:03', 'Temperature': '16.4', 'Humidity': '71.8', 'PM25': '10.0', 'PM25predict': '15.42'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be108>
# topic=pm25, partition=0, offset=53 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 21, 0, 3), 'Temperature': '16.6', 'Humidity': '70.7', 'PM2.5': '9.0', 'PM25predict': '15.55'})
# json= {'timestamp': '2020/01/01 21:00:03', 'Temperature': '16.6', 'Humidity': '70.7', 'PM25': '9.0', 'PM25predict': '15.55'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3a88>
# topic=pm25, partition=0, offset=54 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 22, 0, 3), 'Temperature': '16.7', 'Humidity': '70.7', 'PM2.5': '8.0', 'PM25predict': '15.58'})
# json= {'timestamp': '2020/01/01 22:00:03', 'Temperature': '16.7', 'Humidity': '70.7', 'PM25': '8.0', 'PM25predict': '15.58'}
# <pymongo.results.InsertOneResult object at 0x7f770d789848>
# topic=pm25, partition=0, offset=55 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 1, 23, 0, 4), 'Temperature': '16.7', 'Humidity': '70.8', 'PM2.5': '9.0', 'PM25predict': '15.57'})
# json= {'timestamp': '2020/01/01 23:00:04', 'Temperature': '16.7', 'Humidity': '70.8', 'PM25': '9.0', 'PM25predict': '15.57'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3f88>
# topic=pm25, partition=0, offset=56 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 0, 0, 3), 'Temperature': '16.6', 'Humidity': '71.8', 'PM2.5': '11.0', 'PM25predict': '15.48'})
# json= {'timestamp': '2020/01/02 00:00:03', 'Temperature': '16.6', 'Humidity': '71.8', 'PM25': '11.0', 'PM25predict': '15.48'}
# <pymongo.results.InsertOneResult object at 0x7f7720f43608>
# topic=pm25, partition=0, offset=57 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 1, 0, 4), 'Temperature': '16.8', 'Humidity': '71.4', 'PM2.5': '14.0', 'PM25predict': '15.56'})
# json= {'timestamp': '2020/01/02 01:00:04', 'Temperature': '16.8', 'Humidity': '71.4', 'PM25': '14.0', 'PM25predict': '15.56'}
# <pymongo.results.InsertOneResult object at 0x7f770d7a6f88>
# topic=pm25, partition=0, offset=58 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 2, 0, 3), 'Temperature': '16.9', 'Humidity': '70.9', 'PM2.5': '10.0', 'PM25predict': '15.62'})
# json= {'timestamp': '2020/01/02 02:00:03', 'Temperature': '16.9', 'Humidity': '70.9', 'PM25': '10.0', 'PM25predict': '15.62'}
# <pymongo.results.InsertOneResult object at 0x7f770d7a6ec8>
# topic=pm25, partition=0, offset=59 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 3, 0, 3), 'Temperature': '16.7', 'Humidity': '71.2', 'PM2.5': '11.0', 'PM25predict': '15.54'})
# json= {'timestamp': '2020/01/02 03:00:03', 'Temperature': '16.7', 'Humidity': '71.2', 'PM25': '11.0', 'PM25predict': '15.54'}
# <pymongo.results.InsertOneResult object at 0x7f771f70d6c8>
# topic=pm25, partition=0, offset=60 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 4, 0, 3), 'Temperature': '16.7', 'Humidity': '71.4', 'PM2.5': '20.0', 'PM25predict': '15.53'})
# json= {'timestamp': '2020/01/02 04:00:03', 'Temperature': '16.7', 'Humidity': '71.4', 'PM25': '20.0', 'PM25predict': '15.53'}
# <pymongo.results.InsertOneResult object at 0x7f770d7a6fc8>
# topic=pm25, partition=0, offset=61 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 5, 0, 3), 'Temperature': '16.5', 'Humidity': '72.1', 'PM2.5': '15.0', 'PM25predict': '15.42'})
# json= {'timestamp': '2020/01/02 05:00:03', 'Temperature': '16.5', 'Humidity': '72.1', 'PM25': '15.0', 'PM25predict': '15.42'}
# <pymongo.results.InsertOneResult object at 0x7f771c45d888>
# topic=pm25, partition=0, offset=62 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 6, 0, 3), 'Temperature': '16.6', 'Humidity': '71.3', 'PM2.5': '21.0', 'PM25predict': '15.5'})
# json= {'timestamp': '2020/01/02 06:00:03', 'Temperature': '16.6', 'Humidity': '71.3', 'PM25': '21.0', 'PM25predict': '15.5'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3c08>
# topic=pm25, partition=0, offset=63 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 7, 0, 3), 'Temperature': '16.6', 'Humidity': '70.4', 'PM2.5': '15.0', 'PM25predict': '15.55'})
# json= {'timestamp': '2020/01/02 07:00:03', 'Temperature': '16.6', 'Humidity': '70.4', 'PM25': '15.0', 'PM25predict': '15.55'}
# <pymongo.results.InsertOneResult object at 0x7f771c4cb1c8>
# topic=pm25, partition=0, offset=64 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 8, 0, 4), 'Temperature': '17.6', 'Humidity': '67.0', 'PM2.5': '10.0', 'PM25predict': '16.12'})
# json= {'timestamp': '2020/01/02 08:00:04', 'Temperature': '17.6', 'Humidity': '67.0', 'PM25': '10.0', 'PM25predict': '16.12'}
# <pymongo.results.InsertOneResult object at 0x7f770d7a6fc8>
# topic=pm25, partition=0, offset=65 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 9, 0, 3), 'Temperature': '18.2', 'Humidity': '65.9', 'PM2.5': '14.0', 'PM25predict': '16.38'})
# json= {'timestamp': '2020/01/02 09:00:03', 'Temperature': '18.2', 'Humidity': '65.9', 'PM25': '14.0', 'PM25predict': '16.38'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be1c8>
# topic=pm25, partition=0, offset=66 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 10, 0, 2), 'Temperature': '19.5', 'Humidity': '60.8', 'PM2.5': '12.0', 'PM25predict': '17.11'})
# json= {'timestamp': '2020/01/02 10:00:02', 'Temperature': '19.5', 'Humidity': '60.8', 'PM25': '12.0', 'PM25predict': '17.11'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3ec8>
# topic=pm25, partition=0, offset=67 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 11, 0, 2), 'Temperature': '20.5', 'Humidity': '58.5', 'PM2.5': '14.0', 'PM25predict': '17.57'})
# json= {'timestamp': '2020/01/02 11:00:02', 'Temperature': '20.5', 'Humidity': '58.5', 'PM25': '14.0', 'PM25predict': '17.57'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3b48>
# topic=pm25, partition=0, offset=68 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 12, 0, 3), 'Temperature': '21.5', 'Humidity': '55.5', 'PM2.5': '11.0', 'PM25predict': '18.07'})
# json= {'timestamp': '2020/01/02 12:00:03', 'Temperature': '21.5', 'Humidity': '55.5', 'PM25': '11.0', 'PM25predict': '18.07'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be048>
# topic=pm25, partition=0, offset=69 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 13, 0, 2), 'Temperature': '22.0', 'Humidity': '54.3', 'PM2.5': '12.0', 'PM25predict': '18.3'})
# json= {'timestamp': '2020/01/02 13:00:02', 'Temperature': '22.0', 'Humidity': '54.3', 'PM25': '12.0', 'PM25predict': '18.3'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3fc8>
# topic=pm25, partition=0, offset=70 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 14, 0, 3), 'Temperature': '22.5', 'Humidity': '50.9', 'PM2.5': '13.0', 'PM25predict': '18.67'})
# json= {'timestamp': '2020/01/02 14:00:03', 'Temperature': '22.5', 'Humidity': '50.9', 'PM25': '13.0', 'PM25predict': '18.67'}
# <pymongo.results.InsertOneResult object at 0x7f771c214088>
# topic=pm25, partition=0, offset=71 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 15, 0, 3), 'Temperature': '21.4', 'Humidity': '59.6', 'PM2.5': '14.0', 'PM25predict': '17.79'})
# json= {'timestamp': '2020/01/02 15:00:03', 'Temperature': '21.4', 'Humidity': '59.6', 'PM25': '14.0', 'PM25predict': '17.79'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3f08>
# topic=pm25, partition=0, offset=72 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 16, 0, 4), 'Temperature': '20.3', 'Humidity': '61.9', 'PM2.5': '15.0', 'PM25predict': '17.29'})
# json= {'timestamp': '2020/01/02 16:00:04', 'Temperature': '20.3', 'Humidity': '61.9', 'PM25': '15.0', 'PM25predict': '17.29'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3dc8>
# topic=pm25, partition=0, offset=73 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 17, 0, 3), 'Temperature': '19.8', 'Humidity': '65.5', 'PM2.5': '18.0', 'PM25predict': '16.91'})
# json= {'timestamp': '2020/01/02 17:00:03', 'Temperature': '19.8', 'Humidity': '65.5', 'PM25': '18.0', 'PM25predict': '16.91'}
# <pymongo.results.InsertOneResult object at 0x7f771c4cb1c8>
# topic=pm25, partition=0, offset=74 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 18, 0, 3), 'Temperature': '19.6', 'Humidity': '64.4', 'PM2.5': '17.0', 'PM25predict': '16.91'})
# json= {'timestamp': '2020/01/02 18:00:03', 'Temperature': '19.6', 'Humidity': '64.4', 'PM25': '17.0', 'PM25predict': '16.91'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3ec8>
# topic=pm25, partition=0, offset=75 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 19, 0, 3), 'Temperature': '19.1', 'Humidity': '64.7', 'PM2.5': '17.0', 'PM25predict': '16.73'})
# json= {'timestamp': '2020/01/02 19:00:03', 'Temperature': '19.1', 'Humidity': '64.7', 'PM25': '17.0', 'PM25predict': '16.73'}
# <pymongo.results.InsertOneResult object at 0x7f771f706848>
# topic=pm25, partition=0, offset=76 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 20, 0, 2), 'Temperature': '19.0', 'Humidity': '63.9', 'PM2.5': '17.0', 'PM25predict': '16.74'})
# json= {'timestamp': '2020/01/02 20:00:02', 'Temperature': '19.0', 'Humidity': '63.9', 'PM25': '17.0', 'PM25predict': '16.74'}
# <pymongo.results.InsertOneResult object at 0x7f771c4cb1c8>
# topic=pm25, partition=0, offset=77 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 21, 0, 3), 'Temperature': '18.8', 'Humidity': '64.8', 'PM2.5': '20.0', 'PM25predict': '16.62'})
# json= {'timestamp': '2020/01/02 21:00:03', 'Temperature': '18.8', 'Humidity': '64.8', 'PM25': '20.0', 'PM25predict': '16.62'}
# <pymongo.results.InsertOneResult object at 0x7f770d7be1c8>
# topic=pm25, partition=0, offset=78 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 22, 0, 3), 'Temperature': '18.7', 'Humidity': '65.2', 'PM2.5': '17.0', 'PM25predict': '16.56'})
# json= {'timestamp': '2020/01/02 22:00:03', 'Temperature': '18.7', 'Humidity': '65.2', 'PM25': '17.0', 'PM25predict': '16.56'}
# <pymongo.results.InsertOneResult object at 0x7f770d7a6ec8>
# topic=pm25, partition=0, offset=79 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 2, 23, 0, 3), 'Temperature': '18.6', 'Humidity': '65.8', 'PM2.5': '17.0', 'PM25predict': '16.49'})
# json= {'timestamp': '2020/01/02 23:00:03', 'Temperature': '18.6', 'Humidity': '65.8', 'PM25': '17.0', 'PM25predict': '16.49'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3cc8>
# topic=pm25, partition=0, offset=80 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 3, 0, 0, 3), 'Temperature': '18.5', 'Humidity': '65.5', 'PM2.5': '15.0', 'PM25predict': '16.47'})
# json= {'timestamp': '2020/01/03 00:00:03', 'Temperature': '18.5', 'Humidity': '65.5', 'PM25': '15.0', 'PM25predict': '16.47'}
# <pymongo.results.InsertOneResult object at 0x7f771c4cb1c8>
# topic=pm25, partition=0, offset=81 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 3, 1, 0, 3), 'Temperature': '18.3', 'Humidity': '65.1', 'PM2.5': '12.0', 'PM25predict': '16.43'})
# json= {'timestamp': '2020/01/03 01:00:03', 'Temperature': '18.3', 'Humidity': '65.1', 'PM25': '12.0', 'PM25predict': '16.43'}
# <pymongo.results.InsertOneResult object at 0x7f7720f43608>
# topic=pm25, partition=0, offset=82 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 3, 2, 0, 4), 'Temperature': '18.1', 'Humidity': '65.7', 'PM2.5': '14.0', 'PM25predict': '16.33'})
# json= {'timestamp': '2020/01/03 02:00:04', 'Temperature': '18.1', 'Humidity': '65.7', 'PM25': '14.0', 'PM25predict': '16.33'}
# <pymongo.results.InsertOneResult object at 0x7f771f706848>
# topic=pm25, partition=0, offset=83 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 3, 3, 0, 3), 'Temperature': '18.0', 'Humidity': '65.9', 'PM2.5': '15.0', 'PM25predict': '16.28'})
# json= {'timestamp': '2020/01/03 03:00:03', 'Temperature': '18.0', 'Humidity': '65.9', 'PM25': '15.0', 'PM25predict': '16.28'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3d88>
# topic=pm25, partition=0, offset=84 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 3, 4, 0, 4), 'Temperature': '17.6', 'Humidity': '67.5', 'PM2.5': '18.0', 'PM25predict': '16.05'})
# json= {'timestamp': '2020/01/03 04:00:04', 'Temperature': '17.6', 'Humidity': '67.5', 'PM25': '18.0', 'PM25predict': '16.05'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3a08>
# topic=pm25, partition=0, offset=85 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 3, 5, 0, 3), 'Temperature': '17.3', 'Humidity': '68.5', 'PM2.5': '22.0', 'PM25predict': '15.89'})
# json= {'timestamp': '2020/01/03 05:00:03', 'Temperature': '17.3', 'Humidity': '68.5', 'PM25': '22.0', 'PM25predict': '15.89'}
# <pymongo.results.InsertOneResult object at 0x7f770d7a6fc8>
# topic=pm25, partition=0, offset=86 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 3, 6, 0, 3), 'Temperature': '17.3', 'Humidity': '67.7', 'PM2.5': '25.0', 'PM25predict': '15.94'})
# json= {'timestamp': '2020/01/03 06:00:03', 'Temperature': '17.3', 'Humidity': '67.7', 'PM25': '25.0', 'PM25predict': '15.94'}
# <pymongo.results.InsertOneResult object at 0x7f770d7a6ec8>
# topic=pm25, partition=0, offset=87 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 3, 7, 0, 3), 'Temperature': '17.2', 'Humidity': '67.2', 'PM2.5': '23.0', 'PM25predict': '15.94'})
# json= {'timestamp': '2020/01/03 07:00:03', 'Temperature': '17.2', 'Humidity': '67.2', 'PM25': '23.0', 'PM25predict': '15.94'}
# <pymongo.results.InsertOneResult object at 0x7f771c4cb1c8>
# topic=pm25, partition=0, offset=88 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 3, 8, 0, 3), 'Temperature': '17.9', 'Humidity': '65.2', 'PM2.5': '29.0', 'PM25predict': '16.32'})
# json= {'timestamp': '2020/01/03 08:00:03', 'Temperature': '17.9', 'Humidity': '65.2', 'PM25': '29.0', 'PM25predict': '16.32'}
# <pymongo.results.InsertOneResult object at 0x7f770d7c3ec8>
# topic=pm25, partition=0, offset=89 : (key=None, value={'timestamp': datetime.datetime(2020, 1, 3, 9, 0, 3), 'Temperature': '19.3', 'Humidity': '62.5', 'PM2.5': '25.0', 'PM25predict': '16.94'})
# json= {'timestamp': '2020/01/03 09:00:03', 'Temperature': '19.3', 'Humidity': '62.5', 'PM25': '25.0', 'PM25predict': '16.94'}
# <pymongo.results.InsertOneResult object at 0x7f770d789808>
